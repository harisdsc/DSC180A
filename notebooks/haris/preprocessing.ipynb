# %% [markdown]
# # Phase 1: Preprocessing & Cleaning Text Data

# %% [markdown]
# ## 1. Load Dataset

# %% [markdown]
# ## 2. Define Regular Expressions

# %% [markdown]
# ## 3. Apply Regex

# %% [markdown]
# # Phase 2: Extract & Analyze N-Grams

# %%
from src.preprocessing.ngrams import top_ngrams

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/harissaif/DSC180A/data/memos.csv')['memo']

# %%
print(top_ngrams(df, (1,1)))
# Out:
# Analyzing (1, 1) n-grams...
# ...
